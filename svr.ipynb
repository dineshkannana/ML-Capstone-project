# %%
import pandas as pd

# %%
dataset=pd.read_csv("pre_crop_yield.csv")

# %%
dataset
# Out:
#        Region Soil_Type     Crop  Rainfall_mm  Temperature_Celsius  \
# 0        West     Sandy   Cotton   897.077239            27.676966
# 1       South      Clay     Rice   992.673282            18.026142
# 2       North      Loam   Barley   147.998025            29.794042
# 3       North     Sandy  Soybean   986.866331            16.644190
# 4       South      Silt    Wheat   730.379174            31.620687
# ...       ...       ...      ...          ...                  ...
# 999984   West      Silt     Rice   302.805345            27.987428
# 999985  South    Chalky   Barley   932.991383            39.661039
# 999986  North     Peaty   Cotton   867.362046            24.370042
# 999987   West      Silt    Wheat   492.812857            33.045505
# 999988   West     Sandy    Maize   180.936180            27.298847
#
#         Fertilizer_Used  Irrigation_Used Weather_Condition  Days_to_Harvest  \
# 0                 False             True            Cloudy              122
# 1                  True             True             Rainy              140
# 2                 False            False             Sunny              106
# 3                 False             True             Rainy              146
# 4                  True             True            Cloudy              110
# ...                 ...              ...               ...              ...
# 999984            False            False             Sunny               76
# 999985             True            False             Rainy               93
# 999986             True            False            Cloudy              108
# 999987            False            False             Sunny              102
# 999988             True            False             Sunny               76
#
#         Yield_tons_per_hectare
# 0                     6.555816
# 1                     8.527341
# 2                     1.127443
# 3                     6.517573
# 4                     7.248251
# ...                        ...
# 999984                1.347586
# 999985                7.311594
# 999986                5.763182
# 999987                2.070159
# 999988                2.937243
#
# [999989 rows x 10 columns]

# %%
dataset.columns
# Out:
# Index(['Region', 'Soil_Type', 'Crop', 'Rainfall_mm', 'Temperature_Celsius',
#        'Fertilizer_Used', 'Irrigation_Used', 'Weather_Condition',
#        'Days_to_Harvest', 'Yield_tons_per_hectare'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming 'dataset' is your DataFrame
categorical_columns = ['Crop','Soil_Type','Region','Weather_Condition'] 

for column in categorical_columns:
    le = LabelEncoder()
    dataset[column] = le.fit_transform(dataset[column])
dataset
# Out:
#         Region  Soil_Type  Crop  Rainfall_mm  Temperature_Celsius  \
# 0            3          4     1   897.077239            27.676966
# 1            2          1     3   992.673282            18.026142
# 2            1          2     0   147.998025            29.794042
# 3            1          4     4   986.866331            16.644190
# 4            2          5     5   730.379174            31.620687
# ...        ...        ...   ...          ...                  ...
# 999984       3          5     3   302.805345            27.987428
# 999985       2          0     0   932.991383            39.661039
# 999986       1          3     1   867.362046            24.370042
# 999987       3          5     5   492.812857            33.045505
# 999988       3          4     2   180.936180            27.298847
#
#         Fertilizer_Used  Irrigation_Used  Weather_Condition  Days_to_Harvest  \
# 0                 False             True                  0              122
# 1                  True             True                  1              140
# 2                 False            False                  2              106
# 3                 False             True                  1              146
# 4                  True             True                  0              110
# ...                 ...              ...                ...              ...
# 999984            False            False                  2               76
# 999985             True            False                  1               93
# 999986             True            False                  0              108
# 999987            False            False                  2              102
# 999988             True            False                  2               76
#
#         Yield_tons_per_hectare
# 0                     6.555816
# 1                     8.527341
# 2                     1.127443
# 3                     6.517573
# 4                     7.248251
# ...                        ...
# 999984                1.347586
# 999985                7.311594
# 999986                5.763182
# 999987                2.070159
# 999988                2.937243
#
# [999989 rows x 10 columns]

# %%
dataset.isnull().sum()
# Out:
# Region                    0
# Soil_Type                 0
# Crop                      0
# Rainfall_mm               0
# Temperature_Celsius       0
# Fertilizer_Used           0
# Irrigation_Used           0
# Weather_Condition         0
# Days_to_Harvest           0
# Yield_tons_per_hectare    0
# dtype: int64

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#         Region  Soil_Type  Crop  Rainfall_mm  Temperature_Celsius  \
# 0            3          4     1   897.077239            27.676966
# 1            2          1     3   992.673282            18.026142
# 2            1          2     0   147.998025            29.794042
# 3            1          4     4   986.866331            16.644190
# 4            2          5     5   730.379174            31.620687
# ...        ...        ...   ...          ...                  ...
# 999984       3          5     3   302.805345            27.987428
# 999985       2          0     0   932.991383            39.661039
# 999986       1          3     1   867.362046            24.370042
# 999987       3          5     5   492.812857            33.045505
# 999988       3          4     2   180.936180            27.298847
#
#         Fertilizer_Used  Irrigation_Used  Weather_Condition  Days_to_Harvest  \
# 0                 False             True                  0              122
# 1                  True             True                  1              140
# 2                 False            False                  2              106
# 3                 False             True                  1              146
# 4                  True             True                  0              110
# ...                 ...              ...                ...              ...
# 999984            False            False                  2               76
# 999985             True            False                  1               93
# 999986             True            False                  0              108
# 999987            False            False                  2              102
# 999988             True            False                  2               76
#
#         Yield_tons_per_hectare
# 0                     6.555816
# 1                     8.527341
# 2                     1.127443
# 3                     6.517573
# 4                     7.248251
# ...                        ...
# 999984                1.347586
# 999985                7.311594
# 999986                5.763182
# 999987                2.070159
# 999988                2.937243
#
# [999989 rows x 10 columns]

# %%
dataset.columns
# Out:
# Index(['Region', 'Soil_Type', 'Crop', 'Rainfall_mm', 'Temperature_Celsius',
#        'Fertilizer_Used', 'Irrigation_Used', 'Weather_Condition',
#        'Days_to_Harvest', 'Yield_tons_per_hectare'],
#       dtype='object')

# %%
independent=dataset[['Region', 'Soil_Type', 'Crop', 'Rainfall_mm', 'Temperature_Celsius',
       'Fertilizer_Used', 'Irrigation_Used', 'Weather_Condition',
       'Days_to_Harvest']]

# %%
dependent=dataset[['Yield_tons_per_hectare']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler() 
X_train = sc.fit_transform(X_train) 
X_test = sc.transform(X_test)

# %%
scy = StandardScaler()
y_train = scy.fit_transform(y_train)
y_test = scy.transform(y_test)
y_test
# Out:
# array([[ 0.27494119],
#        [-1.86974694],
#        [ 0.90162296],
#        ...,
#        [-0.6632549 ],
#        [-1.01832315],
#        [-1.22191443]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_regression
import time
from sklearn.svm import SVR 
import numpy as np
from sklearn.preprocessing import StandardScaler 

# Generate some sample data for demonstration
independent, dependent = make_regression(n_samples=100, n_features=5, random_state=42)


scaler = StandardScaler()
independent = scaler.fit_transform(independent)

X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.2, random_state=42)

param_grid = {
    'C': [10,100,1000], 
    'kernel': ['linear', 'rbf','poly','sigmoid'],  
    'epsilon': [0.01, 0.1, 1], 
}

grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1, cv=5)

# Record the start time
start_time = time.time()

# Fit the GridSearchCV object to the training data
grid.fit(X_train, y_train)

# Record the end time
end_time = time.time()

# Calculate the run time
run_time = end_time - start_time

# Print the results
print(f"\nBest parameters found: {grid.best_params_}")
print(f"Best cross-validation score: {grid.best_score_:.4f}")
print(f"GridSearchCV run time: {run_time:.2f} seconds")

# You can now use the best estimator to make predictions
best_svr = grid.best_estimator_
predictions = best_svr.predict(X_test)
print(predictions)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#
# Best parameters found: {'C': 100, 'epsilon': 0.01, 'kernel': 'linear'}
# Best cross-validation score: 1.0000
# GridSearchCV run time: 0.65 seconds
# [ 244.59558194 -149.72640632 -261.92511358   53.32699471 -109.01873336
#   156.57234268 -145.74497791  115.49494057   52.56362576  271.30578492
#   135.86024377  126.71769005 -159.63446867    3.38265228 -221.36190391
#    49.63406125   56.32796337   17.25725969  -49.86534605   73.32212036]

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'C': 100, 'epsilon': 0.01, 'kernel': 'linear'}: 0.9999999986273582

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.056596      0.006767         0.003915        0.001115      10
# 1        0.006925      0.005873         0.002630        0.002538      10
# 2        0.005575      0.003561         0.004317        0.002795      10
# 3        0.003517      0.003403         0.001769        0.001062      10
# 4        0.014688      0.001804         0.003132        0.001339      10
# 5        0.002646      0.001063         0.002415        0.001075      10
# 6        0.002779      0.000744         0.001995        0.000508      10
# 7        0.003009      0.001585         0.002762        0.000775      10
# 8        0.003417      0.001392         0.001613        0.000807      10
# 9        0.002273      0.000932         0.002948        0.000825      10
# 10       0.002927      0.000788         0.002746        0.000901      10
# 11       0.003247      0.000750         0.001721        0.000605      10
# 12       0.074284      0.014946         0.001828        0.000937     100
# 13       0.002623      0.001208         0.002103        0.000173     100
# 14       0.004823      0.002125         0.002114        0.000204     100
# 15       0.003223      0.000985         0.002502        0.000980     100
# 16       0.022801      0.009865         0.002871        0.001044     100
# 17       0.004759      0.000767         0.002317        0.000879     100
# 18       0.005258      0.002063         0.001611        0.000806     100
# 19       0.003621      0.000818         0.001512        0.000900     100
# 20       0.006074      0.001228         0.001661        0.000867     100
# 21       0.003502      0.000713         0.002355        0.000595     100
# 22       0.004422      0.001823         0.002252        0.001446     100
# 23       0.003365      0.001024         0.002795        0.001618     100
# 24       0.068851      0.016328         0.001912        0.001289    1000
# 25       0.009364      0.001967         0.001610        0.000805    1000
# 26       0.036054      0.016353         0.001212        0.001176    1000
# 27       0.002638      0.000834         0.002009        0.001293    1000
# 28       0.023223      0.008937         0.001831        0.000993    1000
# 29       0.009114      0.002355         0.002031        0.001435    1000
# 30       0.031139      0.015399         0.002125        0.001289    1000
# 31       0.003933      0.002019         0.002925        0.000924    1000
# 32       0.005302      0.001225         0.002110        0.000190    1000
# 33       0.006840      0.000931         0.002510        0.000777    1000
# 34       0.075046      0.090576         0.001962        0.001152    1000
# 35       0.003200      0.000996         0.002362        0.000836    1000
#
#    param_epsilon param_kernel  \
# 0           0.01       linear
# 1           0.01          rbf
# 2           0.01         poly
# 3           0.01      sigmoid
# 4            0.1       linear
# 5            0.1          rbf
# 6            0.1         poly
# 7            0.1      sigmoid
# 8              1       linear
# 9              1          rbf
# 10             1         poly
# 11             1      sigmoid
# 12          0.01       linear
# 13          0.01          rbf
# 14          0.01         poly
# 15          0.01      sigmoid
# 16           0.1       linear
# 17           0.1          rbf
# 18           0.1         poly
# 19           0.1      sigmoid
# 20             1       linear
# 21             1          rbf
# 22             1         poly
# 23             1      sigmoid
# 24          0.01       linear
# 25          0.01          rbf
# 26          0.01         poly
# 27          0.01      sigmoid
# 28           0.1       linear
# 29           0.1          rbf
# 30           0.1         poly
# 31           0.1      sigmoid
# 32             1       linear
# 33             1          rbf
# 34             1         poly
# 35             1      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'epsilon': 0.01, 'kernel': 'linear'}           1.000000
# 1         {'C': 10, 'epsilon': 0.01, 'kernel': 'rbf'}           0.262006
# 2        {'C': 10, 'epsilon': 0.01, 'kernel': 'poly'}           0.447253
# 3     {'C': 10, 'epsilon': 0.01, 'kernel': 'sigmoid'}           0.802433
# 4       {'C': 10, 'epsilon': 0.1, 'kernel': 'linear'}           1.000000
# 5          {'C': 10, 'epsilon': 0.1, 'kernel': 'rbf'}           0.262004
# 6         {'C': 10, 'epsilon': 0.1, 'kernel': 'poly'}           0.447212
# 7      {'C': 10, 'epsilon': 0.1, 'kernel': 'sigmoid'}           0.802754
# 8         {'C': 10, 'epsilon': 1, 'kernel': 'linear'}           0.999960
# 9            {'C': 10, 'epsilon': 1, 'kernel': 'rbf'}           0.264167
# 10          {'C': 10, 'epsilon': 1, 'kernel': 'poly'}           0.444965
# 11       {'C': 10, 'epsilon': 1, 'kernel': 'sigmoid'}           0.800671
# 12    {'C': 100, 'epsilon': 0.01, 'kernel': 'linear'}           1.000000
# 13       {'C': 100, 'epsilon': 0.01, 'kernel': 'rbf'}           0.874273
# 14      {'C': 100, 'epsilon': 0.01, 'kernel': 'poly'}           0.331309
# 15   {'C': 100, 'epsilon': 0.01, 'kernel': 'sigmoid'}           0.925954
# 16     {'C': 100, 'epsilon': 0.1, 'kernel': 'linear'}           1.000000
# 17        {'C': 100, 'epsilon': 0.1, 'kernel': 'rbf'}           0.874309
# 18       {'C': 100, 'epsilon': 0.1, 'kernel': 'poly'}           0.329801
# 19    {'C': 100, 'epsilon': 0.1, 'kernel': 'sigmoid'}           0.926062
# 20       {'C': 100, 'epsilon': 1, 'kernel': 'linear'}           0.999980
# 21          {'C': 100, 'epsilon': 1, 'kernel': 'rbf'}           0.874626
# 22         {'C': 100, 'epsilon': 1, 'kernel': 'poly'}           0.318901
# 23      {'C': 100, 'epsilon': 1, 'kernel': 'sigmoid'}           0.877905
# 24   {'C': 1000, 'epsilon': 0.01, 'kernel': 'linear'}           1.000000
# 25      {'C': 1000, 'epsilon': 0.01, 'kernel': 'rbf'}           0.940871
# 26     {'C': 1000, 'epsilon': 0.01, 'kernel': 'poly'}          -0.226110
# 27  {'C': 1000, 'epsilon': 0.01, 'kernel': 'sigmoid'}          -8.553469
# 28    {'C': 1000, 'epsilon': 0.1, 'kernel': 'linear'}           1.000000
# 29       {'C': 1000, 'epsilon': 0.1, 'kernel': 'rbf'}           0.940958
# 30      {'C': 1000, 'epsilon': 0.1, 'kernel': 'poly'}          -0.221879
# 31   {'C': 1000, 'epsilon': 0.1, 'kernel': 'sigmoid'}          -8.543383
# 32      {'C': 1000, 'epsilon': 1, 'kernel': 'linear'}           0.999980
# 33         {'C': 1000, 'epsilon': 1, 'kernel': 'rbf'}           0.941541
# 34        {'C': 1000, 'epsilon': 1, 'kernel': 'poly'}          -0.200464
# 35     {'C': 1000, 'epsilon': 1, 'kernel': 'sigmoid'}          -8.443838
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            1.000000           1.000000           1.000000
# 1            0.412341           0.433274           0.131484
# 2            0.439887           0.489679           0.675824
# 3            0.797163           0.820679           0.728520
# 4            1.000000           1.000000           1.000000
# 5            0.412140           0.433205           0.131476
# 6            0.439936           0.489656           0.675941
# 7            0.796989           0.819388           0.728484
# 8            0.999984           0.999986           0.999963
# 9            0.410105           0.432593           0.130317
# 10           0.440371           0.488410           0.677182
# 11           0.796469           0.816919           0.728726
# 12           1.000000           1.000000           1.000000
# 13           0.948141           0.912103           0.605776
# 14           0.807354           0.779426           0.730962
# 15           0.915778           0.894164           0.932538
# 16           1.000000           1.000000           1.000000
# 17           0.948256           0.912225           0.605859
# 18           0.807221           0.779605           0.730123
# 19           0.919477           0.894176           0.932488
# 20           0.999979           0.999985           0.999974
# 21           0.948645           0.913002           0.606891
# 22           0.807852           0.781286           0.725089
# 23           0.919097           0.894113           0.886699
# 24           1.000000           1.000000           1.000000
# 25           0.958276           0.967121           0.706773
# 26           0.725080           0.820176          -0.063406
# 27          -7.948039          -5.748029          -4.621353
# 28           1.000000           1.000000           1.000000
# 29           0.957972           0.967007           0.706518
# 30           0.725073           0.820250          -0.059712
# 31          -7.949880          -5.749364          -4.622684
# 32           0.999979           0.999985           0.999974
# 33           0.955858           0.964896           0.703387
# 34           0.724211           0.813548          -0.026373
# 35          -7.968550         -17.946171          -4.636175
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            1.000000         1.000000    1.098031e-09                3
# 1            0.267245         0.301270    1.107148e-01               31
# 2            0.410179         0.492564    9.508701e-02               26
# 3            0.778064         0.785372    3.150326e-02               19
# 4            1.000000         1.000000    1.238712e-07                6
# 5            0.267231         0.301211    1.106611e-01               32
# 6            0.410269         0.492603    9.511533e-02               25
# 7            0.778281         0.785179    3.124281e-02               20
# 8            0.999961         0.999971    1.169608e-05                9
# 9            0.267083         0.300853    1.103271e-01               33
# 10           0.411623         0.492510    9.554304e-02               27
# 11           0.779087         0.784374    3.031747e-02               21
# 12           1.000000         1.000000    4.482099e-10                1
# 13           0.839587         0.835976    1.207047e-01               18
# 14           0.775019         0.684814    1.784376e-01               22
# 15           0.941087         0.921904    1.615226e-02               11
# 16           1.000000         1.000000    3.572047e-08                4
# 17           0.839548         0.836040    1.207117e-01               17
# 18           0.775151         0.684380    1.790059e-01               23
# 19           0.941556         0.922752    1.604145e-02               10
# 20           0.999977         0.999979    3.666642e-06                7
# 21           0.839376         0.836508    1.205085e-01               16
# 22           0.775185         0.681663    1.833451e-01               24
# 23           0.951723         0.905907    2.670286e-02               12
# 24           1.000000         1.000000    4.482099e-10                1
# 25           0.913869         0.897382    9.702227e-02               13
# 26           0.652759         0.381700    4.361643e-01               30
# 27          -5.259163        -6.426011    1.544062e+00               35
# 28           1.000000         1.000000    3.572047e-08                4
# 29           0.913543         0.897200    9.706456e-02               14
# 30           0.654638         0.383674    4.344785e-01               29
# 31          -5.253937        -6.423850    1.542013e+00               34
# 32           0.999977         0.999979    3.666642e-06                7
# 33           0.909648         0.895066    9.765792e-02               15
# 34           0.673867         0.396958    4.227155e-01               28
# 35          -5.201998        -8.839346    4.790531e+00               36
